# %% [markdown]
# <a href="https://colab.research.google.com/github/KaranDave31/ML-codes/blob/main/ML_Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Toyota.csv')
df
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300      3
# 1432  10845  72.0     ??   Petrol   86       0.0          0  1300      3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300      3
# 1434   7250  70.0     ??      NaN   86       1.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...

# %%
df.size
# Out:
# 14360

# %%
df.shape
# Out:
# (1436, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1436 non-null   object
#  3   FuelType   1336 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 112.3+ KB

# %%
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Price          int64
# Age          float64
# KM            object
# FuelType      object
# HP            object
# MetColor     float64
# Automatic      int64
# CC             int64
# Doors         object
# Weight         int64
# dtype: object

# %%
df['FuelType'][3]
# Out:
# 'Diesel'

# %%
df.at[3,'FuelType']
# Out:
# 'Diesel'

# %%
df['Age'][4]
# Out:
# 30.0

# %%
df.iat[3,1]
# Out:
# 26.0

# %%
df['FuelType']
# Out:
# 0       Diesel
# 1       Diesel
# 2       Diesel
# 3       Diesel
# 4       Diesel
#          ...
# 1431    Petrol
# 1432    Petrol
# 1433    Petrol
# 1434       NaN
# 1435    Petrol
# Name: FuelType, Length: 1436, dtype: object

# %%
df['KM']
# Out:
# 0       46986
# 1       72937
# 2       41711
# 3       48000
# 4       38500
#         ...
# 1431    20544
# 1432       ??
# 1433    17016
# 1434       ??
# 1435        1
# Name: KM, Length: 1436, dtype: object

# %%
df['HP']
# Out:
# 0        90
# 1        90
# 2        90
# 3        90
# 4        90
#        ...
# 1431     86
# 1432     86
# 1433     86
# 1434     86
# 1435    110
# Name: HP, Length: 1436, dtype: object

# %%
df['Automatic']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1431    0
# 1432    0
# 1433    0
# 1434    0
# 1435    0
# Name: Automatic, Length: 1436, dtype: int64

# %%
df.loc[:,['KM','HP','Automatic']]
# Out:
#          KM   HP  Automatic
# 0     46986   90          0
# 1     72937   90          0
# 2     41711   90          0
# 3     48000   90          0
# 4     38500   90          0
# ...     ...  ...        ...
# 1431  20544   86          0
# 1432     ??   86          0
# 1433  17016   86          0
# 1434     ??   86          0
# 1435      1  110          0
#
# [1436 rows x 3 columns]

# %%
df.iloc[1:5,2:4]
# Out:
#       KM FuelType
# 1  72937   Diesel
# 2  41711   Diesel
# 3  48000   Diesel
# 4  38500   Diesel

# %%
df['KM'].unique()
# Out:
# array(['46986', '72937', '41711', ..., '30964', '20544', '17016'],
#       dtype=object)

# %%
df['KM'].nunique()
# Out:
# 1256

# %%
df['KM'].head(50).unique()
# Out:
# array(['46986', '72937', '41711', '48000', '38500', '61000', '??',
#        '75889', '19700', '71138', '31461', '43610', '32189', '23000',
#        '34131', '18739', '34000', '21716', '25563', '64359', '67660',
#        '43905', '56349', '32220', '25813', '28450', '34545', '41415',
#        '44142', '11090', '9750', '35199', '29510', '32692', '41000',
#        '43000', '25000', '10000', '25329', '27500', '49059', '44068',
#        '46961', '110404', '100250', '84000', '79375', '75048', '72215',
#        '64982'], dtype=object)

# %%
df['HP'].unique()
# Out:
# array(['90', '????', '192', '110', '97', '71', '116', '98', '69', '86',
#        '72', '107', '73'], dtype=object)

# %%
df['HP'].nunique()
# Out:
# 13

# %%
df['Doors'].unique()
# Out:
# array(['three', '3', '5', '4', 'four', 'five', '2'], dtype=object)

# %%
df['Doors'].nunique()
# Out:
# 7

# %%
df = pd.read_csv('/content/drive/MyDrive/ML /Toyota.csv', na_values=['??','????'])
df
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 112.3+ KB

# %%
df['HP'].unique()
# Out:
# array([ 90.,  nan, 192., 110.,  97.,  71., 116.,  98.,  69.,  86.,  72.,
#        107.,  73.])

# %%
df['Doors'].replace('three',3,inplace=True)
df['Doors'].replace('four',4,inplace=True)
df['Doors'].replace('five',5,inplace=True)
# Out:
# <ipython-input-32-6e00725de12d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Doors'].replace('three',3,inplace=True)
# <ipython-input-32-6e00725de12d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df['Doors'].unique()
# Out:
# array([3, '3', '5', '4', 4, 5, '2'], dtype=object)

# %%
df['Doors'] = pd.to_numeric(df['Doors'])

# %%
df['Doors'] = df['Doors'].astype('int64')

# %%
df['Doors'].unique()
# Out:
# array([3, 5, 4, 2])

# %%
df['MetColor'] = df['MetColor'].astype('object')
df['Automatic'] = df['Automatic'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   object
#  6   Automatic  1436 non-null   object
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 112.3+ KB

# %%
df.isnull().sum()
# Out:
# Price          0
# Age          100
# KM            15
# FuelType     100
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1096 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1096 non-null   int64
#  1   Age        1096 non-null   float64
#  2   KM         1096 non-null   float64
#  3   FuelType   1096 non-null   object
#  4   HP         1096 non-null   float64
#  5   MetColor   1096 non-null   object
#  6   Automatic  1096 non-null   object
#  7   CC         1096 non-null   int64
#  8   Doors      1096 non-null   int64
#  9   Weight     1096 non-null   int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 94.2+ KB

# %%
df['FuelType'].value_counts()
# Out:
# FuelType
# Petrol    968
# Diesel    116
# CNG        12
# Name: count, dtype: int64

# %%
mean_km_diesel = df[df['FuelType'] == 'Diesel']['KM'].mean()
mean_km_diesel
# Out:
# 118046.54310344828

# %%
df2 = pd.read_csv('/content/drive/MyDrive/ML /adult.csv')
df2
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df2['relationship'].unique()
# Out:
# array(['Own-child', 'Husband', 'Not-in-family', 'Unmarried', 'Wife',
#        'Other-relative'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df2['Labelencode'] = encoder.fit_transform(df2['relationship'])

# %%
df2
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
one_hot = pd.get_dummies(df2['relationship'])

# %%
df2.encoded = pd.concat([df2,one_hot],axis=1)
# Out:
# <ipython-input-58-150bb7a780e8>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df2.encoded = pd.concat([df2,one_hot],axis=1)

# %%
df2
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df2.encoded
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  ...  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male  ...
# ...
